# %%
#variable 
a=12
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
user=input("Enter your name: ")
print("Hello",user)
print(type(user))
# Out:
# Hello
# <class 'str'>

# %%
user_num = int(input("Enter a number: "))
print("You entered:",user_num)
print(type(user_num))
# Out:
# You entered: 12
# <class 'int'>

# %%
a=10.56
print(a)
b=2+3j
print(b)
print(type(a))
print(type(b))
c=True
print(c)    
print(type(c))
d="Python"
print(d)
print(type(d))
e='a'
print(e)
f="""hiii this is multiline string"""
print(f)
# Out:
# 10.56
# (2+3j)
# <class 'float'>
# <class 'complex'>
# True
# <class 'bool'>
# Python
# <class 'str'>
# a
# hiii this is multiline string

# %%
a=10,2,3,4,5
print(a)
print(type(a))
# Out:
# (10, 2, 3, 4, 5)
# <class 'tuple'>

# %%
tuple_dict = dict(enumerate(a))
print(tuple_dict)
